# %% [markdown]
# # Guess random number game

# %%
from game_v2_1 import score_game, random_predict

# %% [markdown]
# ## Guessing randomly (evaluation done on 1000 tries)

# %%
score_game(random_predict)
# Out:
# tries 6, number 38
# tries 3, number 13
# tries 6, number 73
# tries 5, number 10
# tries 6, number 76
# tries 7, number 6
# tries 7, number 80
# tries 5, number 65
# tries 6, number 17
# tries 6, number 2
# tries 7, number 77
# tries 7, number 72
# tries 4, number 7
# tries 6, number 26
# tries 6, number 51
# tries 7, number 21
# tries 4, number 19
# tries 6, number 85
# tries 7, number 12
# tries 6, number 29
# tries 7, number 30
# tries 7, number 15
# tries 6, number 51
# tries 6, number 69
# tries 6, number 88
# tries 6, number 88
# tries 7, number 95
# tries 7, number 97
# tries 3, number 87
# tries 6, number 14
# tries 5, number 10
# tries 6, number 8
# tries 7, number 64
# tries 3, number 62
# tries 6, number 23
# tries 7, number 58
# tries 6, number 2
# tries 7, number 1
# tries 7, number 61
# tries 6, number 82
# tries 7, number 9
# tries 7, number 89
# tries 6, number 14
# tries 6, number 48
# tries 6, number 73
# tries 4, number 31
# tries 7, number 72
# tries 5, number 4
# ...
